# %%
example_segment = '../Example_1/b0c9d2329ad1606b|2018-08-02--08-34-47/40/'

# %%
import os
import numpy as np
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# We can read the raw logs with logreader
# from openpilot tools
from openpilot_tools.lib.logreader import LogReader

lr = LogReader(example_segment + 'raw_log.bz2')
# Make list of logs
logs = list(lr)
# we print the types of the first 50 logs
print [l.which() for l in logs[:50]]

# we can plot the speed of the car by getting
# all the carState logs
figsize(12,12);
plot([l.carState.vEgo for l in logs if l.which() == 'carState'], linewidth=3);
title('Car speed from raw logs (m/s)', fontsize=25);
xlabel('boot time (s)', fontsize=18);
ylabel('speed (m/s)', fontsize=18);
# Out:
# ['initData', 'sensorEvents', 'live100', 'sendcan', 'carState', 'carControl', 'logMessage', 'can', 'plan', 'can', 'sendcan', 'sensorEvents', 'sensorEvents', 'carState', 'live100', 'carControl', 'logMessage', 'logMessage', 'logMessage', 'can', 'encodeIdx', 'encodeIdx', 'plan', 'live100', 'sendcan', 'carState', 'carControl', 'sensorEvents', 'can', 'logMessage', 'logMessage', 'live20', 'liveTracks', 'can', 'sensorEvents', 'liveLongitudinalMpc', 'can', 'plan', 'liveLongitudinalMpc', 'sendcan', 'sensorEvents', 'sensorEvents', 'sensorEvents', 'live100', 'carState', 'carControl', 'can', 'frame', 'sensorEvents', 'sensorEvents']

# %%
# We can extract frames from the video with framereader
# from openpilot tools, we look at frame 600
from openpilot_tools.lib.framereader import FrameReader
frame_index = 600

fr = FrameReader(example_segment + 'video.hevc')
figsize(12,12)
imshow(fr.get(frame_index, pix_fmt='rgb24')[0]);
title('Frame 600 extracted from video with FrameReader', fontsize=25);
